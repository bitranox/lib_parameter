# %%
# Install a pip package in the current Jupyter kernel
# upgrading setuptools
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools
# Out:
# Requirement already up-to-date: pip in /srv/conda/envs/notebook/lib/python3.7/site-packages (20.1.1)
# Collecting setuptools
#   Downloading setuptools-49.1.0-py3-none-any.whl (789 kB)
#      |████████████████████████████████| 789 kB 3.4 MB/s eta 0:00:01
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 47.1.1.post20200529
#     Uninstalling setuptools-47.1.1.post20200529:
#       Successfully uninstalled setuptools-47.1.1.post20200529
# Successfully installed setuptools-49.1.0

# %%
# install lib-parameter
# !{sys.executable} -m pip install lib_parameter
# Out:
# Collecting lib_parameter
#   Downloading lib_parameter-0.0.2-py3-none-any.whl (4.5 kB)
# Collecting pathlib
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
#      |████████████████████████████████| 49 kB 2.0 MB/s eta 0:00:011
# Collecting typing
#   Downloading typing-3.7.4.1-py3-none-any.whl (25 kB)
# Building wheels for collected packages: pathlib
#   Building wheel for pathlib (setup.py) ... done
#   Created wheel for pathlib: filename=pathlib-1.0.1-py3-none-any.whl size=14346 sha256=4e8f04df38af362435d953de633d6c950bb4c82de7714b6066ff56688f25fc4a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/6e/96/b8/10037fe231e23970bac58361d7c93571ab983a7bbc55e68550
# Successfully built pathlib
# Installing collected packages: pathlib, typing, lib-parameter
# Successfully installed lib-parameter-0.0.2 pathlib-1.0.1 typing-3.7.4.1

# %%
import lib_parameter
x=None
y=lib_parameter.get_default_if_none(parameter=x, default=5)
print(y)
# Out:
# 5
